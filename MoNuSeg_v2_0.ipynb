# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import sys
import cv2
import random
import zipfile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.transforms.functional as TF

from torch.utils.data import DataLoader, TensorDataset, Dataset
from skimage.util.shape import view_as_windows
from sklearn.model_selection import train_test_split
from sklearn.metrics import jaccard_score
from google.colab.patches import cv2_imshow
from PIL import Image
from tqdm import tqdm

# %%
cd /content/drive/My Drive
# Out:
# /content/drive/My Drive

# %%
# !mkdir checkpoint
# Out:
# mkdir: cannot create directory ‘checkpoint’: File exists

# %%
cd /content/drive/My Drive
# Out:
# /content/drive/My Drive

# %%
# !mkdir best_checkpoint

# %%
TRAIN_IMG_PATH = '/content/drive/My Drive/MoNuSeg-Training-Data/MoNuSeg-Training-Data/Norm-Tissue-Images/'
IMG_H, IMG_W = 1000, 1000

img_list = next(os.walk(TRAIN_IMG_PATH))[2]

total_imgs = 0
for img in img_list:
    total_imgs += 1

# %%
X_train = np.zeros((total_imgs, IMG_H, IMG_W, 3), dtype = np.uint8)
Y_train = np.zeros((total_imgs, IMG_H, IMG_W, 3), dtype = np.uint8)

print('Getting Training Data...')
sys.stdout.flush()

for n, img_name in tqdm(enumerate(img_list), total = total_imgs):
    
    img_path = TRAIN_IMG_PATH + img_name
    img = cv2.imread(img_path)[:, :, :3]
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    X_train[n] = img

    mask_path = '/content/drive/My Drive/MoNuSeg-Training-Data/MoNuSeg-Training-Data/Binary-Mask/' + img_name

    mask = cv2.imread(mask_path)
    Y_train[n] = mask

print('Done!')
# Out:
# Getting Training Data...
# 100%|██████████| 30/30 [01:14<00:00,  2.50s/it]
# Done!

# %%
print(Y_train.shape)
# Out:
# (30, 1000, 1000, 3)

# %%
class Nuc_Aug(Dataset):
    
    def __init__(self, images_np, masks_np):
        self.images_np = images_np
        self.masks_np = masks_np
    
    def transform(self, image_np, mask_np):
        
        ToPILImage = transforms.ToPILImage()
        image = ToPILImage(image_np)
        mask = ToPILImage(mask_np)

        h, w = IMG_H, IMG_W
        crop_h, crop_w = 256, 256
        i = random.randint(0, h - crop_h)
        j = random.randint(0, w - crop_w)
        image = TF.crop(image, i, j, crop_h, crop_w)
        mask = TF.crop(mask, i, j, crop_h, crop_w)
        
        image = TF.to_tensor(image)
        mask = TF.to_tensor(mask)
        
        return image, mask
        
    def __len__(self):
        
        return len(self.images_np)
    
    def __getitem__(self, idx):
        image_np = self.images_np[idx]
        mask_np = self.masks_np[idx]

        image, mask = self.transform(image_np, mask_np)
        
        return image, mask

# %%
class Nuc_Aug_v2(Dataset):
    
    def __init__(self, images_np, masks_np):
        self.images_np = images_np
        self.masks_np = masks_np
    
    def transform(self, image_np, mask_np):
        
        ToPILImage = transforms.ToPILImage()
        image = ToPILImage(image_np)
        mask = ToPILImage(mask_np)

        image = TF.to_tensor(image)
        mask = TF.to_tensor(mask)
        
        return image, mask
        
    def __len__(self):
        
        return len(self.images_np)
    
    def __getitem__(self, idx):
        image_np = self.images_np[idx]
        mask_np = self.masks_np[idx]

        image, mask = self.transform(image_np, mask_np)
        
        return image, mask

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = 0.2, random_state = 42)

train_dataset = Nuc_Aug_v2(X_train, Y_train)
train_loader = DataLoader(train_dataset)

val_dataset = Nuc_Aug_v2(X_val, Y_val)
val_loader = DataLoader(val_dataset)

# %%
# %matplotlib inline

for ex_img, ex_mask in train_loader:
    
    img = np.array(TF.to_pil_image(ex_img[0]))
    mask = np.array(TF.to_pil_image(ex_mask[0]))
    
    fig, (axis_1, axis_2) = plt.subplots(1, 2)
    axis_1.imshow(img.astype(np.uint8))
    axis_2.imshow(mask.astype(np.uint8))
    
    break

# %%
def conv_block_a(in_channels, out_channels, drop_rate, *args, **kwargs):

    return nn.Sequential(
        nn.Conv2d(in_channels, out_channels, *args, **kwargs),
        nn.ReLU(),
        nn.Dropout2d(drop_rate),
        nn.MaxPool2d((2, 2), stride = 2)
    )

def conv_block_b(in_channels, out_channels, drop_rate, *args, **kwargs):

    return nn.Sequential(
        nn.Conv2d(in_channels, out_channels, *args, **kwargs),
        nn.ReLU(),
        nn.Dropout2d(drop_rate),
        nn.MaxPool2d((2, 2), stride = 2, padding = 1)
    )

def fc_block(in_units, out_units, drop_rate, *args, **kwargs):

    return nn.Sequential(
        nn.Linear(in_units, out_units, *args, **kwargs),
        nn.ReLU(),
        nn.Dropout(drop_rate)
    )

# %%
class Patch_Seg(nn.Module):

    def __init__(self):

        super().__init__()
    
        self.conv_blocks = nn.Sequential(
            conv_block_a(3, 25, 0.1, kernel_size = (4, 4)),
            conv_block_a(25, 50, 0.2, kernel_size = (5, 5)),
            conv_block_b(50, 80, 0.25, kernel_size = (6, 6))
        )

        self.fc_blocks = nn.Sequential(
            fc_block(720, 1024, 0.5),
            fc_block(1024, 1024, 0.5)
        )

        #self.final = nn.Linear(1024, 2)
        self.final = nn.Linear(1024, 1)

    def forward(self, x):

        x = self.conv_blocks(x)

        x = x.view(-1, 720)
    
        x = self.fc_blocks(x)

        #out = F.softmax(self.final(x), dim = 1)
        out = torch.sigmoid(self.final(x))

        return out

# %%
model = Patch_Seg()
model = model.float()
model = model.to(device)
print(model)

total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(total_params)
# Out:
# Patch_Seg(
#   (conv_blocks): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 25, kernel_size=(4, 4), stride=(1, 1))
#       (1): ReLU()
#       (2): Dropout2d(p=0.1, inplace=False)
#       (3): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (1): Sequential(
#       (0): Conv2d(25, 50, kernel_size=(5, 5), stride=(1, 1))
#       (1): ReLU()
#       (2): Dropout2d(p=0.2, inplace=False)
#       (3): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): Sequential(
#       (0): Conv2d(50, 80, kernel_size=(6, 6), stride=(1, 1))
#       (1): ReLU()
#       (2): Dropout2d(p=0.25, inplace=False)
#       (3): MaxPool2d(kernel_size=(2, 2), stride=2, padding=1, dilation=1, ceil_mode=False)
#     )
#   )
#   (fc_blocks): Sequential(
#     (0): Sequential(
#       (0): Linear(in_features=720, out_features=1024, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.5, inplace=False)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=1024, out_features=1024, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.5, inplace=False)
#     )
#   )
#   (final): Linear(in_features=1024, out_features=1, bias=True)
# )
# 1965534

# %%
class Patch_Aug(Dataset):
    
    def __init__(self, images_np):
        self.images_np = images_np
    
    def transform(self, image_np):
        
        ToPILImage = transforms.ToPILImage()
        image = ToPILImage(image_np)

        if random.random() > 0.5:
            image = TF.hflip(image)

        if random.random() > 0.5:
            image = TF.vflip(image)

        angle_list = [0, 90, 180, 270]
        angle_index = random.randint(0, 3)
        angle = angle_list[angle_index]
        image = TF.affine(image, scale = 1, angle = angle, translate = (0,0), shear = 0)
        
        image = TF.to_tensor(image)
        
        return image
        
    def __len__(self):
        
        return len(self.images_np)
    
    def __getitem__(self, idx):
        image_np = self.images_np[idx]

        image = self.transform(image_np)
        
        return image

# %%
opt = optim.Adam(model.parameters(), lr = 0.001)
loss_func = nn.BCELoss()
lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(opt, patience = 5, verbose = 1)

# %%
def fit(model, num_epochs, opt, lr_scheduler, loss_func, train_loader, val_loader, start_epoch, best_val_loss, best_val_acc, iteration_change_loss, patience):
    
    best_val_loss = best_val_loss
    best_val_acc = best_val_acc
    iteration_change_loss = iteration_change_loss
    patience = patience
    
    for epoch in range(start_epoch, num_epochs + 1):

        model.train()

        epoch_loss = 0
        epoch_correct = 0

        for image, mask in train_loader:

            X = np.array(TF.to_pil_image(image[0]))
            Y = np.array(TF.to_pil_image(mask[0]))

            train_loss = 0
            correct = 0

            img = TF.to_pil_image(X)
            img = TF.pad(img, padding = 25, padding_mode = 'reflect')
            img = np.array(img)

            img_windows = view_as_windows(img, (51, 51, 3))

            one_count = 0
            true_one_count = 0

            for j in range(75):
                
                opt.zero_grad()
                loss = 0

                for k in range(128):

                    idx_1 = random.randint(0, 999)
                    idx_2 = random.randint(0, 999)
      
                    patch_img = img_windows[idx_1, idx_2]
                    patch_aug = Patch_Aug(patch_img)
                    patch_img_aug = patch_aug.__getitem__(0)

                    '''
                    patch_img_np = np.array(TF.to_pil_image(patch_img_aug))
                    plt.imshow(patch_img_np)
                    plt.show()
                    '''

                    patch_img_aug = patch_img_aug.to(device)
                    patch_img_aug = patch_img_aug.unsqueeze(0)

                    patch_label = torch.zeros((1, 1), dtype = np.bool)
                    patch_label = patch_label.to(device)

                    if Y[idx_1][idx_2][0] == 255:
                        patch_label[0][0] = 1

                    else:
                        patch_label[0][0] = 0

                    out = model(patch_img_aug.float())
                    
                    if out[0][0] > 0.5:
                        out_pred = 1

                    else:
                        out_pred = 0 
                    
                    #out_pred = torch.argmax(out, dim = 1)
                    #true_pred = patch_label.squeeze(-1)
                    
                    #if out_pred == true_pred:
                    if out_pred == patch_label[0][0]:
                        correct += 1
                    
                    #loss += loss_func(out, true_pred.long()) 
                    loss += loss_func(out.float(), patch_label.float()) 

                    del patch_img, patch_label

                loss = loss/float(128)
                train_loss += loss

                loss.backward()
                opt.step()

            del img_windows

            epoch_loss += train_loss
            epoch_correct += correct

            print("Epoch: ", epoch, "| Training Loss in Image: ", train_loss/float(75), "| Accuracy: ", correct/float(75*128))
            sys.stdout.flush()

        
        model.eval()

        with torch.no_grad():
        
            epoch_valid_loss = 0
            epoch_valid_correct = 0

            for image, mask in val_loader:

                X = np.array(TF.to_pil_image(image[0]))
                Y = np.array(TF.to_pil_image(mask[0]))

                valid_loss = 0
                correct = 0

                img = TF.to_pil_image(X)
                img = TF.pad(img, padding = 25, padding_mode = 'reflect')
                img = np.array(img)

                img_windows = view_as_windows(img, (51, 51, 3))
            
                for j in range(150):
                
                    for k in range(50):

                        idx_1 = random.randint(0, 999)
                        idx_2 = random.randint(0, 999)
      
                        patch_img = img_windows[idx_1, idx_2]
                        patch_img = TF.to_tensor(TF.to_pil_image(patch_img[0]))
                        patch_img = patch_img.unsqueeze(0)
                        patch_img = patch_img.to(device)

                        patch_label = torch.zeros((1, 1), dtype = np.bool)
                        patch_label = patch_label.to(device)

                        if Y[idx_1][idx_2][0] == 255:
                            patch_label[0][0] = 1

                        else:
                            patch_label[0][0] = 0

                        out = model(patch_img.float())

                        if out[0][0] > 0.5:
                            out_pred = 1

                        else:
                            out_pred = 0 
                    
                        #out_pred = torch.argmax(out, dim = 1)
                        #true_pred = patch_label.squeeze(-1)
                    
                        #if out_pred == true_pred:
                        if out_pred == patch_label[0][0]:
                            correct += 1
                    
                        #loss = loss_func(out, true_pred.long())
                        loss = loss_func(out.float(), patch_label.float())
                        valid_loss += loss

                        del patch_img, patch_label

                del img_windows

                epoch_valid_loss += valid_loss
                epoch_valid_correct += correct

            
            if epoch % 10 == 0:
                
                pred_img = torch.zeros((1000, 1000))

                for image, mask in val_loader:

                    X = np.array(TF.to_pil_image(image[0]))
                    Y = np.array(TF.to_pil_image(mask[0]))

                    correct = 0

                    img = TF.to_pil_image(X)
                    img = TF.pad(img, padding = 25, padding_mode = 'reflect')
                    img = np.array(img)

                    img_windows = view_as_windows(img, (51, 51, 3))
            
                    for j in range(1000):
                
                        for k in range(1000):
      
                            patch_img = img_windows[j, k]
                            patch_img = TF.to_tensor(TF.to_pil_image(patch_img[0]))
                            patch_img = patch_img.unsqueeze(0)
                            patch_img = patch_img.to(device)

                            patch_label = torch.zeros((1, 1), dtype = np.bool)
                            patch_label = patch_label.to(device)

                            if Y[j][k][0] == 255:
                                patch_label[0][0] = 1

                            else:
                                patch_label[0][0] = 0

                            out = model(patch_img.float())

                            if out[0][0] > 0.5:
                                out_pred = 1

                            else:
                                out_pred = 0 
                    
                            #out_pred = torch.argmax(out, dim = 1)

                            pred_img[j][k] = out_pred

                            #true_pred = patch_label.squeeze(-1)
                    
                            #if out_pred == true_pred:
                            if out_pred == patch_label[0][0]:
                                correct += 1

                            del patch_img, patch_label

                    del img_windows

                    print('Accuracy on val image: ', correct/float(1000*1000))

                    pred_np = np.array(TF.to_pil_image(pred_img))
                    mask_np = np.array(TF.to_pil_image(mask[0]))
                    
                    fig, (axis_1, axis_2) = plt.subplots(1, 2)
                    axis_1.imshow(pred_np.astype(np.uint8), cmap = 'gray')
                    axis_2.imshow(mask_np.astype(np.uint8))
                    plt.show()

                    break    

        ovr_train_loss = epoch_loss/float(24*75)
        ovr_train_acc = epoch_correct/float(24*75*128) 
        ovr_val_loss =  epoch_valid_loss/float(6*50*150)
        ovr_val_acc =  epoch_valid_correct/float(6*50*150)

        print("Epoch: ", epoch, "| Epoch Loss: ", ovr_train_loss, "| Epoch Accuracy: ", ovr_train_acc)
        print("Epoch Valid Loss: ", ovr_val_loss, "| Epoch Valid Accuracy: ", ovr_val_acc)
        sys.stdout.flush()

        lr_scheduler.step(ovr_val_loss)

        iteration_change_loss += 1
        print('-' * 30)

        if ovr_val_loss < best_val_loss:
            best_val_loss = ovr_val_loss
            iteration_change_loss = 0

        state = {
        'epoch': epoch + 1,
        'model_state_dict': model.state_dict(),
        'opt_state_dict': opt.state_dict(),
        'lr_state_dict': lr_scheduler.state_dict(),
        'loss': ovr_train_loss,
        'accuracy': ovr_train_acc,
        'best_val_loss': best_val_loss, 
        'best_val_acc': best_val_acc, 
        'iteration_change_loss': iteration_change_loss, 
        'patience': patience
        }

        torch.save(state, '/content/drive/My Drive/monuseg_checkpoint/new_current_checkpoint.pt')

        if ovr_val_acc > best_val_acc:
            best_val_acc = ovr_val_acc

            print('Saving best model...')
            sys.stdout.flush()

            torch.save(model.state_dict(), '/content/drive/My Drive/best_checkpoint/best_current_checkpoint.pt')

        if iteration_change_loss == patience:
            print('Early stopping after {0} iterations without the decrease of the val loss'.format(iteration_change_loss))
            sys.stdout.flush()

            break

# %%
fit(model, 100, opt, lr_scheduler, loss_func, train_loader, val_loader, 0, float('inf'), float(0), 0, 15)
# Out:
# Epoch:  0  Training Loss in Image:  tensor(0.5091, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.750625
# Epoch:  0  Training Loss in Image:  tensor(0.4284, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.8007291666666667
# Epoch:  0  Training Loss in Image:  tensor(0.2982, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.8742708333333333
# Epoch:  0  Training Loss in Image:  tensor(0.2275, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.9044791666666666
# Epoch:  0  Training Loss in Image:  tensor(0.2588, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.8827083333333333
# Epoch:  0  Training Loss in Image:  tensor(0.1534, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.936875
# Epoch:  0  Training Loss in Image:  tensor(0.1882, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.9267708333333333
# Epoch:  0  Training Loss in Image:  tensor(0.3279, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.8580208333333333
# Epoch:  0  Training Loss in Image:  tensor(0.2629, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.8896875
# Epoch:  0  Training Loss in Image:  tensor(0.4586, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.7959375
# Epoch:  0  Training Loss in Image:  tensor(0.2804, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.8777083333333333
# Epoch:  0  Training Loss in Image:  tensor(0.3249, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.8588541666666667
# Epoch:  0  Training Loss in Image:  tensor(0.2614, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.8910416666666666
# Epoch:  0  Training Loss in Image:  tensor(0.3243, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.85375
# Epoch:  0  Training Loss in Image:  tensor(0.2845, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.8719791666666666
# Epoch:  0  Training Loss in Image:  tensor(0.2761, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.8847916666666666
# Epoch:  0  Training Loss in Image:  tensor(0.2530, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.8923958333333334
# Epoch:  0  Training Loss in Image:  tensor(0.2661, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.8826041666666666
# Epoch:  0  Training Loss in Image:  tensor(0.3483, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.8410416666666667
# Epoch:  0  Training Loss in Image:  tensor(0.1294, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.9441666666666667
# Epoch:  0  Training Loss in Image:  tensor(0.1869, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.9291666666666667
# Epoch:  0  Training Loss in Image:  tensor(0.2862, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.87625
# Epoch:  0  Training Loss in Image:  tensor(0.3140, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.8563541666666666
# Epoch:  0  Training Loss in Image:  tensor(0.3411, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.8514583333333333
# Accuracy on val image:  0.92757
# Epoch:  0  Epoch Loss:  tensor(0.2912, device='cuda:0', grad_fn=<DivBackward0>)  Epoch Accuracy:  0.8721527777777778
# Epoch Valid Loss:  tensor(0.2557, device='cuda:0')  Epoch Valid Accuracy:  0.8942666666666667
# ------------------------------
# Saving best model...
# Epoch:  1  Training Loss in Image:  tensor(0.3501, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.8523958333333334
# Epoch:  1  Training Loss in Image:  tensor(0.3604, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.8365625
# Epoch:  1  Training Loss in Image:  tensor(0.2597, device='cuda:0', grad_fn=<DivBackward0>)  Accuracy:  0.886875

# %%
model = Patch_Seg()
model = model.float()
model = model.to(device)

opt = optim.Adam(model.parameters(), lr = 0.01)
lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(opt, patience = 5, verbose = 1)

# %%
checkpoint = torch.load('/content/drive/My Drive/monuseg_checkpoint/new_current_checkpoint.pt')
start_epoch = checkpoint['epoch']
model.load_state_dict(checkpoint['model_state_dict'])
opt.load_state_dict(checkpoint['opt_state_dict'])
lr_scheduler.load_state_dict(checkpoint['lr_state_dict'])
loss = checkpoint['loss']
accuracy = checkpoint['accuracy']
best_val_loss = checkpoint['best_val_loss'] 
best_val_acc = checkpoint['best_val_acc']
iteration_change_loss = checkpoint['iteration_change_loss']
patience = checkpoint['patience']

print("Epoch: ", start_epoch - 1, "| Epoch Loss: ", loss, "| Epoch Accuracy: ", accuracy)
sys.stdout.flush()
# Out:
# Epoch:  41 | Epoch Loss:  tensor(0.2669, device='cuda:0', requires_grad=True) | Epoch Accuracy:  0.8857118055555555

# %%
fit(model, 100, opt, lr_scheduler, loss_func, train_loader, val_loader, start_epoch, best_val_loss, best_val_acc, iteration_change_loss, patience)
# Out:
# Epoch:  34 | Training Loss in Image:  tensor(0.3269, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8585416666666666
# Epoch:  34 | Training Loss in Image:  tensor(0.3257, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.855
# Epoch:  34 | Training Loss in Image:  tensor(0.2313, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9023958333333333
# Epoch:  34 | Training Loss in Image:  tensor(0.1640, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9319791666666667
# Epoch:  34 | Training Loss in Image:  tensor(0.2828, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.87875
# Epoch:  34 | Training Loss in Image:  tensor(0.1402, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9420833333333334
# Epoch:  34 | Training Loss in Image:  tensor(0.1537, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9408333333333333
# Epoch:  34 | Training Loss in Image:  tensor(0.3196, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8570833333333333
# Epoch:  34 | Training Loss in Image:  tensor(0.2822, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8807291666666667
# Epoch:  34 | Training Loss in Image:  tensor(0.5016, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.7914583333333334
# Epoch:  34 | Training Loss in Image:  tensor(0.2459, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.88875
# Epoch:  34 | Training Loss in Image:  tensor(0.3245, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8548958333333333
# Epoch:  34 | Training Loss in Image:  tensor(0.2483, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8913541666666667
# Epoch:  34 | Training Loss in Image:  tensor(0.2995, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8678125
# Epoch:  34 | Training Loss in Image:  tensor(0.2560, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8910416666666666
# Epoch:  34 | Training Loss in Image:  tensor(0.2882, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8785416666666667
# Epoch:  34 | Training Loss in Image:  tensor(0.2951, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8686458333333333
# Epoch:  34 | Training Loss in Image:  tensor(0.2419, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8966666666666666
# Epoch:  34 | Training Loss in Image:  tensor(0.3132, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8620833333333333
# Epoch:  34 | Training Loss in Image:  tensor(0.1704, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9319791666666667
# Epoch:  34 | Training Loss in Image:  tensor(0.1433, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9427083333333334
# Epoch:  34 | Training Loss in Image:  tensor(0.3036, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8683333333333333
# Epoch:  34 | Training Loss in Image:  tensor(0.2634, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8890625
# Epoch:  34 | Training Loss in Image:  tensor(0.2793, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8788541666666667
# Epoch:  34 | Epoch Loss:  tensor(0.2667, device='cuda:0', grad_fn=<DivBackward0>) | Epoch Accuracy:  0.8853993055555556
# Epoch Valid Loss:  tensor(0.2173, device='cuda:0') | Epoch Valid Accuracy:  0.9092666666666667
# ------------------------------
# Epoch:  35 | Training Loss in Image:  tensor(0.3333, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8532291666666667
# Epoch:  35 | Training Loss in Image:  tensor(0.3347, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8507291666666666
# Epoch:  35 | Training Loss in Image:  tensor(0.2320, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9038541666666666
# Epoch:  35 | Training Loss in Image:  tensor(0.1654, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9310416666666667
# Epoch:  35 | Training Loss in Image:  tensor(0.2863, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8789583333333333
# Epoch:  35 | Training Loss in Image:  tensor(0.1384, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9432291666666667
# Epoch:  35 | Training Loss in Image:  tensor(0.1636, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9352083333333333
# Epoch:  35 | Training Loss in Image:  tensor(0.3225, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.85625
# Epoch:  35 | Training Loss in Image:  tensor(0.2808, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.885
# Epoch:  35 | Training Loss in Image:  tensor(0.5010, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.7975
# Epoch:  35 | Training Loss in Image:  tensor(0.2393, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8976041666666666
# Epoch:  35 | Training Loss in Image:  tensor(0.3082, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8625
# Epoch:  35 | Training Loss in Image:  tensor(0.2441, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8945833333333333
# Epoch:  35 | Training Loss in Image:  tensor(0.3076, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8663541666666666
# Epoch:  35 | Training Loss in Image:  tensor(0.2580, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8867708333333333
# Epoch:  35 | Training Loss in Image:  tensor(0.2845, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8803125
# Epoch:  35 | Training Loss in Image:  tensor(0.2864, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8703125
# Epoch:  35 | Training Loss in Image:  tensor(0.2533, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8876041666666666
# Epoch:  35 | Training Loss in Image:  tensor(0.3118, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8617708333333334
# Epoch:  35 | Training Loss in Image:  tensor(0.1750, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9296875
# Epoch:  35 | Training Loss in Image:  tensor(0.1475, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9386458333333333
# Epoch:  35 | Training Loss in Image:  tensor(0.3133, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8570833333333333
# Epoch:  35 | Training Loss in Image:  tensor(0.2601, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8873958333333334
# Epoch:  35 | Training Loss in Image:  tensor(0.2868, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8738541666666667
# Epoch:  35 | Epoch Loss:  tensor(0.2681, device='cuda:0', grad_fn=<DivBackward0>) | Epoch Accuracy:  0.8845616319444445
# Epoch Valid Loss:  tensor(0.2151, device='cuda:0') | Epoch Valid Accuracy:  0.9101111111111111
# ------------------------------
# Saving best model...
# Epoch:  36 | Training Loss in Image:  tensor(0.3402, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8546875
# Epoch:  36 | Training Loss in Image:  tensor(0.3244, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8551041666666667
# Epoch:  36 | Training Loss in Image:  tensor(0.2260, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9034375
# Epoch:  36 | Training Loss in Image:  tensor(0.1711, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9323958333333333
# Epoch:  36 | Training Loss in Image:  tensor(0.2837, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.87625
# Epoch:  36 | Training Loss in Image:  tensor(0.1401, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9430208333333333
# Epoch:  36 | Training Loss in Image:  tensor(0.1660, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9361458333333333
# Epoch:  36 | Training Loss in Image:  tensor(0.3364, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8479166666666667
# Epoch:  36 | Training Loss in Image:  tensor(0.2730, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8873958333333334
# Epoch:  36 | Training Loss in Image:  tensor(0.4940, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.7953125
# Epoch:  36 | Training Loss in Image:  tensor(0.2336, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.899375
# Epoch:  36 | Training Loss in Image:  tensor(0.3152, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8616666666666667
# Epoch:  36 | Training Loss in Image:  tensor(0.2526, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.891875
# Epoch:  36 | Training Loss in Image:  tensor(0.3062, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8682291666666667
# Epoch:  36 | Training Loss in Image:  tensor(0.2597, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8909375
# Epoch:  36 | Training Loss in Image:  tensor(0.2810, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8869791666666667
# Epoch:  36 | Training Loss in Image:  tensor(0.2857, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8739583333333333
# Epoch:  36 | Training Loss in Image:  tensor(0.2432, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8951041666666667
# Epoch:  36 | Training Loss in Image:  tensor(0.3070, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8647916666666666
# Epoch:  36 | Training Loss in Image:  tensor(0.1670, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.933125
# Epoch:  36 | Training Loss in Image:  tensor(0.1459, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9408333333333333
# Epoch:  36 | Training Loss in Image:  tensor(0.3040, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8655208333333333
# Epoch:  36 | Training Loss in Image:  tensor(0.2762, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8832291666666666
# Epoch:  36 | Training Loss in Image:  tensor(0.2930, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.87375
# Epoch:  36 | Epoch Loss:  tensor(0.2677, device='cuda:0', grad_fn=<DivBackward0>) | Epoch Accuracy:  0.8858767361111111
# Epoch Valid Loss:  tensor(0.2174, device='cuda:0') | Epoch Valid Accuracy:  0.9075333333333333
# ------------------------------
# Epoch:  37 | Training Loss in Image:  tensor(0.3392, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8484375
# Epoch:  37 | Training Loss in Image:  tensor(0.3219, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8565625
# Epoch:  37 | Training Loss in Image:  tensor(0.2351, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8994791666666667
# Epoch:  37 | Training Loss in Image:  tensor(0.1704, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9311458333333333
# Epoch:  37 | Training Loss in Image:  tensor(0.2896, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8776041666666666
# Epoch:  37 | Training Loss in Image:  tensor(0.1402, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9433333333333334
# Epoch:  37 | Training Loss in Image:  tensor(0.1616, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9370833333333334
# Epoch:  37 | Training Loss in Image:  tensor(0.3208, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8539583333333334
# Epoch:  37 | Training Loss in Image:  tensor(0.2889, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8770833333333333
# Epoch:  37 | Training Loss in Image:  tensor(0.4952, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.7896875
# Epoch:  37 | Training Loss in Image:  tensor(0.2389, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8959375
# Epoch:  37 | Training Loss in Image:  tensor(0.3091, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8636458333333333
# Epoch:  37 | Training Loss in Image:  tensor(0.2411, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8945833333333333
# Epoch:  37 | Training Loss in Image:  tensor(0.3022, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8765625
# Epoch:  37 | Training Loss in Image:  tensor(0.2483, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8980208333333334
# Epoch:  37 | Training Loss in Image:  tensor(0.2888, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8809375
# Epoch:  37 | Training Loss in Image:  tensor(0.2884, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8723958333333334
# Epoch:  37 | Training Loss in Image:  tensor(0.2508, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8927083333333333
# Epoch:  37 | Training Loss in Image:  tensor(0.3056, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8639583333333334
# Epoch:  37 | Training Loss in Image:  tensor(0.1762, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9259375
# Epoch:  37 | Training Loss in Image:  tensor(0.1417, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9442708333333333
# Epoch:  37 | Training Loss in Image:  tensor(0.3199, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8605208333333333
# Epoch:  37 | Training Loss in Image:  tensor(0.2642, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8838541666666667
# Epoch:  37 | Training Loss in Image:  tensor(0.2836, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8732291666666666
# Epoch:  37 | Epoch Loss:  tensor(0.2676, device='cuda:0', grad_fn=<DivBackward0>) | Epoch Accuracy:  0.8850390625
# Epoch Valid Loss:  tensor(0.2159, device='cuda:0') | Epoch Valid Accuracy:  0.9087111111111111
# ------------------------------
# Epoch:  38 | Training Loss in Image:  tensor(0.3378, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8541666666666666
# Epoch:  38 | Training Loss in Image:  tensor(0.3451, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8439583333333334
# Epoch:  38 | Training Loss in Image:  tensor(0.2355, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9022916666666667
# Epoch:  38 | Training Loss in Image:  tensor(0.1684, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9313541666666667
# Epoch:  38 | Training Loss in Image:  tensor(0.2831, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8860416666666666
# Epoch:  38 | Training Loss in Image:  tensor(0.1444, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9427083333333334
# Epoch:  38 | Training Loss in Image:  tensor(0.1676, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.934375
# Epoch:  38 | Training Loss in Image:  tensor(0.3209, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8553125
# Epoch:  38 | Training Loss in Image:  tensor(0.2750, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8835416666666667
# Epoch:  38 | Training Loss in Image:  tensor(0.4807, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8014583333333334
# Epoch:  38 | Training Loss in Image:  tensor(0.2380, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8984375
# Epoch:  38 | Training Loss in Image:  tensor(0.3045, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8661458333333333
# Epoch:  38 | Training Loss in Image:  tensor(0.2350, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8998958333333333
# Epoch:  38 | Training Loss in Image:  tensor(0.3003, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8701041666666667
# Epoch:  38 | Training Loss in Image:  tensor(0.2640, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8901041666666667
# Epoch:  38 | Training Loss in Image:  tensor(0.2815, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8841666666666667
# Epoch:  38 | Training Loss in Image:  tensor(0.2914, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8716666666666667
# Epoch:  38 | Training Loss in Image:  tensor(0.2536, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8902083333333334
# Epoch:  38 | Training Loss in Image:  tensor(0.3059, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8658333333333333
# Epoch:  38 | Training Loss in Image:  tensor(0.1694, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9314583333333334
# Epoch:  38 | Training Loss in Image:  tensor(0.1406, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9448958333333334
# Epoch:  38 | Training Loss in Image:  tensor(0.3084, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8667708333333334
# Epoch:  38 | Training Loss in Image:  tensor(0.2628, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8898958333333333
# Epoch:  38 | Training Loss in Image:  tensor(0.2853, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8716666666666667
# Epoch:  38 | Epoch Loss:  tensor(0.2666, device='cuda:0', grad_fn=<DivBackward0>) | Epoch Accuracy:  0.8865190972222222
# Epoch Valid Loss:  tensor(0.2140, device='cuda:0') | Epoch Valid Accuracy:  0.9091555555555556
# Epoch    39: reducing learning rate of group 0 to 1.0000e-06.
# ------------------------------
# Epoch:  39 | Training Loss in Image:  tensor(0.3336, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8551041666666667
# Epoch:  39 | Training Loss in Image:  tensor(0.3341, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8533333333333334
# Epoch:  39 | Training Loss in Image:  tensor(0.2245, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9028125
# Epoch:  39 | Training Loss in Image:  tensor(0.1555, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9351041666666666
# Epoch:  39 | Training Loss in Image:  tensor(0.2809, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8827083333333333
# Epoch:  39 | Training Loss in Image:  tensor(0.1520, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9421875
# Epoch:  39 | Training Loss in Image:  tensor(0.1730, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.935625
# Epoch:  39 | Training Loss in Image:  tensor(0.3838, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8291666666666667
# Epoch:  39 | Training Loss in Image:  tensor(0.2361, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8966666666666666
# Epoch:  39 | Training Loss in Image:  tensor(0.4542, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8067708333333333
# Epoch:  39 | Training Loss in Image:  tensor(0.2447, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8896875
# Epoch:  39 | Training Loss in Image:  tensor(0.3204, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.856875
# Epoch:  39 | Training Loss in Image:  tensor(0.2396, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8960416666666666
# Epoch:  39 | Training Loss in Image:  tensor(0.3051, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8639583333333334
# Epoch:  39 | Training Loss in Image:  tensor(0.2488, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8948958333333333
# Epoch:  39 | Training Loss in Image:  tensor(0.2898, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8789583333333333
# Epoch:  39 | Training Loss in Image:  tensor(0.2750, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8789583333333333
# Epoch:  39 | Training Loss in Image:  tensor(0.2376, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8951041666666667
# Epoch:  39 | Training Loss in Image:  tensor(0.3181, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8554166666666667
# Epoch:  39 | Training Loss in Image:  tensor(0.1936, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9205208333333333
# Epoch:  39 | Training Loss in Image:  tensor(0.1448, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9441666666666667
# Epoch:  39 | Training Loss in Image:  tensor(0.2926, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8717708333333334
# Epoch:  39 | Training Loss in Image:  tensor(0.2600, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8922916666666667
# Epoch:  39 | Training Loss in Image:  tensor(0.2807, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.87375
# Epoch:  39 | Epoch Loss:  tensor(0.2658, device='cuda:0', grad_fn=<DivBackward0>) | Epoch Accuracy:  0.8854947916666667
# Epoch Valid Loss:  tensor(0.2141, device='cuda:0') | Epoch Valid Accuracy:  0.9102666666666667
# ------------------------------
# Saving best model...
# Epoch:  40 | Training Loss in Image:  tensor(0.3680, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8458333333333333
# Epoch:  40 | Training Loss in Image:  tensor(0.3323, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8501041666666667
# Epoch:  40 | Training Loss in Image:  tensor(0.2400, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8948958333333333
# Epoch:  40 | Training Loss in Image:  tensor(0.1625, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.93125
# Epoch:  40 | Training Loss in Image:  tensor(0.2797, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8836458333333334
# Epoch:  40 | Training Loss in Image:  tensor(0.1498, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9419791666666667
# Epoch:  40 | Training Loss in Image:  tensor(0.1705, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9354166666666667
# Epoch:  40 | Training Loss in Image:  tensor(0.3631, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8411458333333334
# Epoch:  40 | Training Loss in Image:  tensor(0.2503, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8934375
# Epoch:  40 | Training Loss in Image:  tensor(0.4752, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.7928125
# Epoch:  40 | Training Loss in Image:  tensor(0.2342, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8994791666666667
# Epoch:  40 | Training Loss in Image:  tensor(0.3138, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8576041666666666
# Epoch:  40 | Training Loss in Image:  tensor(0.2392, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8984375
# Epoch:  40 | Training Loss in Image:  tensor(0.3074, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.864375
# Epoch:  40 | Training Loss in Image:  tensor(0.2530, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8907291666666667
# Epoch:  40 | Training Loss in Image:  tensor(0.2837, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.883125
# Epoch:  40 | Training Loss in Image:  tensor(0.2785, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.879375
# Epoch:  40 | Training Loss in Image:  tensor(0.2414, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8978125
# Epoch:  40 | Training Loss in Image:  tensor(0.3044, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8686458333333333
# Epoch:  40 | Training Loss in Image:  tensor(0.1901, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9214583333333334
# Epoch:  40 | Training Loss in Image:  tensor(0.1462, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9447916666666667
# Epoch:  40 | Training Loss in Image:  tensor(0.2907, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8730208333333334
# Epoch:  40 | Training Loss in Image:  tensor(0.2625, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8922916666666667
# Epoch:  40 | Training Loss in Image:  tensor(0.2918, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8761458333333333
# Accuracy on val image:  0.935763
# Epoch:  40 | Epoch Loss:  tensor(0.2679, device='cuda:0', grad_fn=<DivBackward0>) | Epoch Accuracy:  0.8857421875
# Epoch Valid Loss:  tensor(0.2119, device='cuda:0') | Epoch Valid Accuracy:  0.9095555555555556
# ------------------------------
# Epoch:  41 | Training Loss in Image:  tensor(0.3479, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8536458333333333
# Epoch:  41 | Training Loss in Image:  tensor(0.3282, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.85375
# Epoch:  41 | Training Loss in Image:  tensor(0.2255, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.903125
# Epoch:  41 | Training Loss in Image:  tensor(0.1666, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9297916666666667
# Epoch:  41 | Training Loss in Image:  tensor(0.2863, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8777083333333333
# Epoch:  41 | Training Loss in Image:  tensor(0.1457, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9436458333333333
# Epoch:  41 | Training Loss in Image:  tensor(0.1714, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9372916666666666
# Epoch:  41 | Training Loss in Image:  tensor(0.3613, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8378125
# Epoch:  41 | Training Loss in Image:  tensor(0.2522, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8919791666666667
# Epoch:  41 | Training Loss in Image:  tensor(0.4879, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.7917708333333333
# Epoch:  41 | Training Loss in Image:  tensor(0.2395, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8957291666666667
# Epoch:  41 | Training Loss in Image:  tensor(0.3019, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.865
# Epoch:  41 | Training Loss in Image:  tensor(0.2414, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8965625
# Epoch:  41 | Training Loss in Image:  tensor(0.3044, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8661458333333333
# Epoch:  41 | Training Loss in Image:  tensor(0.2554, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8913541666666667
# Epoch:  41 | Training Loss in Image:  tensor(0.2848, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8840625
# Epoch:  41 | Training Loss in Image:  tensor(0.2719, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8828125
# Epoch:  41 | Training Loss in Image:  tensor(0.2461, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8934375
# Epoch:  41 | Training Loss in Image:  tensor(0.3076, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8652083333333334
# Epoch:  41 | Training Loss in Image:  tensor(0.1971, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9179166666666667
# Epoch:  41 | Training Loss in Image:  tensor(0.1406, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.9434375
# Epoch:  41 | Training Loss in Image:  tensor(0.2856, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8741666666666666
# Epoch:  41 | Training Loss in Image:  tensor(0.2783, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8847916666666666
# Epoch:  41 | Training Loss in Image:  tensor(0.2774, device='cuda:0', grad_fn=<DivBackward0>) | Accuracy:  0.8759375
# Epoch:  41 | Epoch Loss:  tensor(0.2669, device='cuda:0', grad_fn=<DivBackward0>) | Epoch Accuracy:  0.8857118055555555
# Epoch Valid Loss:  tensor(0.2121, device='cuda:0') | Epoch Valid Accuracy:  0.9106222222222222
# ------------------------------
# Saving best model...
# Early stopping after 15 iterations without the decrease of the val loss

# %%
best_checkpoint = torch.load('/content/drive/My Drive/best_checkpoint/best_current_checkpoint.pt')
model.load_state_dict(best_checkpoint)
# Out:
# <All keys matched successfully>

# %%
def noise_filter(pred_img, iterations):

    for n in range(iterations):    
        
        for i in range(1000):
            
            for j in range(1000):

                count_zero = 0
                count_one = 0

                try:
                    if pred_img[i][j-1] == 0:
                        count_zero += 1

                except:
                    pass

                try:
                    if pred_img[i][j+1] == 0:
                        count_zero += 1

                except:
                    pass

                try:
                    if pred_img[i-1][j] == 0:
                        count_zero += 1

                except:
                    pass

                try:
                    if pred_img[i+1][j] == 0:
                        count_zero += 1

                except:
                    pass

                try:
                    if pred_img[i][j-1] == 1:
                        count_one += 1

                except:
                    pass

                try:
                    if pred_img[i][j+1] == 1:
                        count_one += 1

                except:
                    pass

                try:
                    if pred_img[i-1][j] == 1:
                        count_one += 1

                except:
                    pass

                try:
                    if pred_img[i+1][j] == 1:
                        count_one += 1

                except:
                    pass

                if count_zero >= 3:
                    pred_img[i][j] = 0

                if count_one >= 3:
                    pred_img[i][j] = 1

    return pred_img

# %%
jac_index = 0

for image, mask in val_loader:
    
    pred_img = torch.zeros((1000, 1000))
    true_img = torch.zeros((3, 1000, 1000))

    true_img = mask[0]

    X = np.array(TF.to_pil_image(image[0]))
    Y = np.array(TF.to_pil_image(mask[0]))

    correct = 0

    img = TF.to_pil_image(X)
    img = TF.pad(img, padding = 25, padding_mode = 'reflect')
    img = np.array(img)

    img_windows = view_as_windows(img, (51, 51, 3))
            
    for j in range(1000):
                
        for k in range(1000):
      
            patch_img = img_windows[j, k]
            patch_img = TF.to_tensor(TF.to_pil_image(patch_img[0]))
            patch_img = patch_img.unsqueeze(0)
            patch_img = patch_img.to(device)

            patch_label = torch.zeros((1, 1), dtype = np.bool)
            patch_label = patch_label.to(device)

            if Y[j][k][0] == 255:
                patch_label[0][0] = 1

            else:
                patch_label[0][0] = 0

            out = model(patch_img.float())

            if out[0][0] > 0.5:
                out_pred = 1

            else:
                out_pred = 0 
                    
            pred_img[j][k] = out_pred
                    
            if out_pred == patch_label[0][0]:
                correct += 1

            del patch_img, patch_label

    del img_windows

    print('Accuracy on val image: ', correct/float(1000*1000))

    '''
    pred_np = np.array(TF.to_pil_image(pred_img))
    mask_np = np.array(TF.to_pil_image(mask[0]))

                   
    fig, (axis_1, axis_2) = plt.subplots(1, 2)
    axis_1.imshow(pred_np.astype(np.uint8), cmap = 'gray')
    axis_2.imshow(mask_np.astype(np.uint8))
    plt.show()
    '''

    true_np = np.array(TF.to_pil_image(true_img))
    true_gray = cv2.cvtColor(true_np, cv2.COLOR_BGR2GRAY)
    true_tensor = TF.to_tensor(TF.to_pil_image(true_gray))
    true_mask = true_tensor[0]

    pred_modified = noise_filter(pred_img, 1)

    pred_flat = pred_modified.view(-1)
    true_flat = true_mask.view(-1)
    score = jaccard_score(pred_flat, true_flat)
    print("Jaccard Index: ", score)

    jac_index += score

    pred_orig_np = np.array(TF.to_pil_image(pred_img)) 
    pred_np = np.array(TF.to_pil_image(pred_modified))
    true_np = np.array(TF.to_pil_image(true_img))

    fig, (axis_1, axis_2, axis_3) = plt.subplots(1, 3)
    axis_1.imshow(pred_orig_np.astype(np.uint8))
    axis_1.set_title("Before Noise Filter")
    axis_2.imshow(pred_np.astype(np.uint8))
    axis_2.set_title("After Noise Filter")
    axis_3.imshow(true_np.astype(np.uint8))
    axis_3.set_title("True Mask")
    plt.show()
    
    print("True Image")
    cv2_imshow(X)
    print("\n")
    print("After Noise Filter")
    cv2_imshow(pred_np)
    print("\n")
    print("True Mask")
    cv2_imshow(true_np)
    print("\n")

print("Average Jaccard Index over validation set: ", jac_index/len(val_loader))

# %%
# Modifying and testing on one val image

pred_img = torch.zeros((1000, 1000))
true_img = torch.zeros((3, 1000, 1000))

for image, mask in val_loader:

    true_img = mask[0]

    X = np.array(TF.to_pil_image(image[0]))
    Y = np.array(TF.to_pil_image(mask[0]))

    correct = 0

    img = TF.to_pil_image(X)
    img = TF.pad(img, padding = 25, padding_mode = 'reflect')
    img = np.array(img)

    img_windows = view_as_windows(img, (51, 51, 3))
            
    for j in range(1000):
                
        for k in range(1000):
      
            patch_img = img_windows[j, k]
            patch_img = TF.to_tensor(TF.to_pil_image(patch_img[0]))
            patch_img = patch_img.unsqueeze(0)
            patch_img = patch_img.to(device)

            patch_label = torch.zeros((1, 1), dtype = np.bool)
            patch_label = patch_label.to(device)

            if Y[j][k][0] == 255:
                patch_label[0][0] = 1

            else:
                patch_label[0][0] = 0

            out = model(patch_img.float())

            if out[0][0] > 0.5:
                out_pred = 1

            else:
                out_pred = 0 
                    
            pred_img[j][k] = out_pred
                    
            if out_pred == patch_label[0][0]:
                correct += 1

            del patch_img, patch_label

    del img_windows

    print('Accuracy on val image: ', correct/float(1000*1000))

    pred_np = np.array(TF.to_pil_image(pred_img))
    mask_np = np.array(TF.to_pil_image(mask[0]))

    fig, (axis_1, axis_2) = plt.subplots(1, 2)
    axis_1.imshow(pred_np.astype(np.uint8), cmap = 'gray')
    axis_2.imshow(mask_np.astype(np.uint8))
    plt.show()

    break
# Out:
# Accuracy on val image:  0.932389

# %%
true_alt = true_img

true_np = np.array(TF.to_pil_image(true_alt))
true_gray = cv2.cvtColor(true_np, cv2.COLOR_BGR2GRAY)
true_tensor = TF.to_tensor(TF.to_pil_image(true_gray))

true_mask = true_tensor[0]

print(pred_img.shape)
print(true_mask.shape)
# Out:
# torch.Size([1000, 1000])
# torch.Size([1000, 1000])

# %%
pred_flat = pred_img.view(-1)
true_flat = true_mask.view(-1)
score = jaccard_score(pred_flat, true_flat)
print(score)
# Out:
# 0.6822537514745068

# %%
pred_modified = noise_filter(pred_img, 1)

pred_flat = pred_modified.view(-1)
true_flat = true_mask.view(-1)
score = jaccard_score(pred_flat, true_flat)
print("Jaccard Index: ", score)

pred_np = np.array(TF.to_pil_image(pred_modified))
true_np = np.array(TF.to_pil_image(true_mask))

print("After Noise Filtering")
cv2_imshow(pred_np)
print("\n True Mask")
cv2_imshow(true_np)
# Out:
# Jaccard Index:  0.6985208741107947
# After Noise Filtering
# <PIL.Image.Image image mode=L size=1000x1000 at 0x7F4FF86A8780>
#  True Mask
# <PIL.Image.Image image mode=L size=1000x1000 at 0x7F4FF86A8EB8>

# %%
pred_mod_alias_np = np.array(TF.to_pil_image(pred_modified))

# noise removal
kernel = np.ones((3,3),np.uint8)
opening = cv2.morphologyEx(pred_mod_alias_np, cv2.MORPH_OPEN, kernel, iterations = 3)

cv2_imshow(opening)
opening_ten = TF.to_tensor(TF.to_pil_image(opening))

opening_flat = opening_ten.view(-1)
true_flat = true_mask.view(-1)
score = jaccard_score(opening_flat, true_flat)
print("Jaccard Index: ", score)
# Out:
# <PIL.Image.Image image mode=L size=1000x1000 at 0x7F4FF6C7FC88>
# Jaccard Index:  0.6803751032505709

# %%
# sure background area
sure_bg = cv2.dilate(opening,kernel,iterations=1)

# Finding sure foreground area
dist_transform = cv2.distanceTransform(opening,cv2.DIST_L2,3)
ret, sure_fg = cv2.threshold(dist_transform,0.7*dist_transform.max(),255,0)

# Finding unknown region
sure_fg = np.uint8(sure_fg)
unknown = cv2.subtract(sure_bg,sure_fg)

cv2_imshow(dist_transform)
cv2_imshow(sure_fg)
# Out:
# <PIL.Image.Image image mode=L size=1000x1000 at 0x7F4FF86A84A8>
# <PIL.Image.Image image mode=L size=1000x1000 at 0x7F4FF86A8588>

# %%
print(pred_mod_alias_np.shape)

img = np.zeros((1000, 1000, 3), dtype = np.uint8)
img[:,:,0] = pred_mod_alias_np
img[:,:,1] = pred_mod_alias_np
img[:,:,2] = pred_mod_alias_np

print(img.shape)
# Out:
# (1000, 1000)
# (1000, 1000, 3)

# %%
ret, markers = cv2.connectedComponents(sure_fg)

# Add one to all labels so that sure background is not 0, but 1
markers = markers+1

# Now, mark the region of unknown with zero
markers[unknown==255] = 0
plt.imshow(markers, cmap = 'jet')
plt.show()

markers = cv2.watershed(img, markers)
img[markers == -1] = [255,0,0]

cv2_imshow(markers)
# Out:
# <PIL.Image.Image image mode=L size=1000x1000 at 0x7F4FF6726DA0>

# %%
pred_modified_np = np.array(TF.to_pil_image(pred_modified))

kernel = np.ones((2, 2), np.uint8)
pred_modified_np = cv2.erode(pred_modified_np, kernel, iterations = 1)
#pred_modified_np = cv2.dilate(pred_modified_np, kernel, iterations = 1)

# %%
cv2_imshow(pred_modified_np)
# Out:
# <PIL.Image.Image image mode=L size=1000x1000 at 0x7F1A61DC84A8>

# %%
pred_mod = TF.to_tensor(TF.to_pil_image(pred_modified_np))

pred_flat = pred_mod.view(-1)
true_flat = true_mask.view(-1)
score = jaccard_score(pred_flat, true_flat)
print(score)
# Out:
# 0.6027825988994934

# %%
from google.colab.patches import cv2_imshow

pred_np = np.array(TF.to_pil_image(pred_img))
true_np = np.array(TF.to_pil_image(true_mask))

params = cv2.SimpleBlobDetector_Params()

params.filterByCircularity = True
params.minCircularity = 0.8

detector = cv2.SimpleBlobDetector_create(params)

keypoints = detector.detect(pred_np)

blank = np.zeros((1, 1))  
blobs = cv2.drawKeypoints(pred_np, keypoints, blank, (0, 0, 255), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

cv2_imshow(blobs) 
print(" ")
cv2_imshow(true_np)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000 at 0x7F1A65E41B38>
# <PIL.Image.Image image mode=L size=1000x1000 at 0x7F1A65E416A0>
